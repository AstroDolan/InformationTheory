# %% [markdown]
# ### Importamos librerias

# %%
import numpy as np
import scipy as sp
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Importamos los csv como Dataframes

# %%
DIAG1 = pd.read_csv(r"DIAG1.csv", sep="\t", encoding="latin-1")
DIAG1
# Out:
#         ID                                              Glosa  casos
# 0    A150   TUBERCULOSIS PULMON, CONFIRM.POR HALLAZGO MICR...   1671
# 1    A151   TUBERCULOSIS DEL PULMON, CONFIRMADA UNICAMENTE...    141
# 2    A152   TUBERCULOSIS DEL PULMON, CONFIRMADA HISTOLOGIC...    326
# 3    A153   TUBERCULOSIS DEL PULMON, CONFIRMADA POR MEDIOS...    215
# 4    A154   TUBERCULOSIS DE GANGLIOS LINFATICOS INTRATORAC...     77
# ..     ...                                                ...    ...
# 488  T405                          ENVENENAMIENTO POR COCAINA    485
# 489  T406   ENVENENAMIENTO POR OTROS NARCOTICOS Y POR LOS ...     28
# 490  T407             ENVENENAMIENTO POR CANNABIS (DERIVADOS)     75
# 491  T408            ENVENENAMIENTO POR ACIDO LISERGICO (LSD)     10
# 492  T409   ENVENENAMIENTO POR OTROS PSICODISLEPTICOS Y PO...     41
#
# [493 rows x 3 columns]

# %%
ORIGEN = pd.read_csv(r"PAIS_ORIGEN.csv", sep="\t", encoding="latin-1")
ORIGEN
# Out:
#       ID                                              Glosa   casos
# 0      0                                                NaN  146388
# 1      4                                         Afganistán      36
# 2      5                                    América del Sur       2
# 3      8                                            Albania       5
# 4     12                                            Argelia      16
# ..   ...                                                ...     ...
# 132  840  Estados Unidos de América Estados Unidos de Am...     363
# 133  858                                            Uruguay     176
# 134  862               Venezuela (República Bolivariana de)    1606
# 135  887                                              Yemen       1
# 136  890                                         Yugoslavia       4
#
# [137 rows x 3 columns]

# %%
casos_chile = PAIS[PAIS['Glosa'].str.contains('Chile', na=False)]

plt.figure(figsize=(10, 6))
plt.scatter(casos_chile['ID'], casos_chile['casos'])
plt.title('Casos de Diagnósticos de Chile')
plt.xlabel('ID')
plt.ylabel('Casos')
plt.show()

# %%
sns.scatterplot(x=ORIGEN[ORIGEN["Glosa"].str.contains("Chile", na=False)], y=DIAG1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sns.scatterplot(x=ORIGEN[ORIGEN["Glosa"].str.contains("Chile", na=False)], y=DIAG1)
#
# File c:\Users\djara\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\relational.py:615, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     606 def scatterplot(
#     607     data=None, *,
#     608     x=None, y=None, hue=None, size=None, style=None,
#    (...)
#     612     **kwargs
#     613 ):
# --> 615     p = _ScatterPlotter(
#     616         data=data,
#     617         variables=dict(x=x, y=y, hue=hue, size=size, style=style),
#     618         legend=legend
#     619     )
#     621     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
# ...
